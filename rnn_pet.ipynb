# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
#load the dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
#pad the sequences to have the same length
maxlen = 500
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
#build the model
model = Sequential()

# %%
model.add(tf.keras.Input(shape=(maxlen,)))
model.add(
    Embedding(
        input_dim=10000,  # Vocabulary size
        output_dim=32,    # Embedding dimension
        input_length=maxlen  # Length of input sequences
    )
)
# Out:
# c:\Users\bsais\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.add(
    SimpleRNN(32)
)

# %%
model.add(
    Dense(1, activation="sigmoid")
)

# %%
#model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 500, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 322,113 (1.23 MB)
#  Trainable params: 322,113 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#model compile
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
#train the model
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - accuracy: 0.6911 - loss: 0.5629 - val_accuracy: 0.8276 - val_loss: 0.4011
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.8429 - loss: 0.3730 - val_accuracy: 0.8378 - val_loss: 0.3881
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8937 - loss: 0.2705 - val_accuracy: 0.8253 - val_loss: 0.3968
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - accuracy: 0.9257 - loss: 0.2013 - val_accuracy: 0.8589 - val_loss: 0.3526
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 22s 85ms/step - accuracy: 0.9472 - loss: 0.1435 - val_accuracy: 0.8414 - val_loss: 0.4319
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.9686 - loss: 0.0950 - val_accuracy: 0.8520 - val_loss: 0.4666
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - accuracy: 0.9845 - loss: 0.0529 - val_accuracy: 0.8430 - val_loss: 0.4979
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.9925 - loss: 0.0329 - val_accuracy: 0.8448 - val_loss: 0.5873
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.9962 - loss: 0.0180 - val_accuracy: 0.8424 - val_loss: 0.6071
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - accuracy: 0.9842 - loss: 0.0498 - val_accuracy: 0.8321 - val_loss: 0.6444

# %%
#model evaluation
loss, accuracy = model.evaluate(x_test, y_test)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8321 - loss: 0.6444
# Accuracy: 83.21%

# %%
model.save("imdb_rnn_model.keras")
